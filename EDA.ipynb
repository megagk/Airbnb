# %% [markdown]
# Interesting Questions
#
# Host:
# - Number of properties the avg/median Airbnb host has
# - Where are the Hosts from (host_location)
# - Hosts period (how long have they been hosts)
#
# Property:
# - Number of reviews
# - Anything interesting within the reviews?
#
# Location:
# - Where are the Airbnbs generally located? Suburb/Neighbourhood
# - Is there a lack of rentals within this area? (Check REA Site)
#
# Price:
# - Average/median price per night

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# - Quarterly data from the last 12 months ending 10 June 2025

# %%
df = pd.read_csv('Data/sydney_airbnb_data.csv')

# %%
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  11156  https://www.airbnb.com/rooms/11156  20250610032053   2025-06-17
# 1  15253  https://www.airbnb.com/rooms/15253  20250610032053   2025-06-17
# 2  44545  https://www.airbnb.com/rooms/44545  20250610032053   2025-06-17
# 3  58506  https://www.airbnb.com/rooms/58506  20250610032053   2025-06-17
# 4  68999  https://www.airbnb.com/rooms/68999  20250610032053   2025-06-17
#
#         source                                                name  \
# 0  city scrape                                An Oasis in the City
# 1  city scrape  Unique Designer Rooftop Apartment in City Location
# 2  city scrape              Sunny Darlinghurst Warehouse Apartment
# 3  city scrape                       Studio Yindi @ Mosman, Sydney
# 4  city scrape                  A little bit of Sydney - Australia
#
# ...
